# %% [markdown]
# # Python Training
#
# Welcome to the Pierian Data's Basic Python Training!
#
# ## Instructor
#
# My name is Jose Portilla and I will be your instructor for this course. I'm currently the Head of Data Science at [Pierian Data Inc.](www.pieriandata.com). I also teach courses on Udemy to thousands of students, including [The Complete Python Bootcamp](https://www.udemy.com/complete-python-bootcamp) and [Python for Data Analysis and Visualization](https://www.udemy.com/learning-python-for-data-analysis-and-visualization) and [Python for Data Structures,Algorithms, and Interviews](https://www.udemy.com/python-for-data-structures-algorithms-and-interviews/).
#
# Feel free to connect with me on [LinkedIn!](https://www.linkedin.com/in/jmportilla)
#
# For this training course in conjunction with NetCom Learning we will be covering the following topics:
#
# * Python Refresher
# * NumPy - Linear Algebra Library
# * Matplotlib - Plotting Library
# * Pandas - Data Analysis Library
# * Sci-Kit Learn - Machine Learning Library
#
#
# We'll have exercises along the way and the course will be very interactive! Let's go ahead and see the planned schedule for the 3 days!

# %% [markdown]
# # ______
# ____
#
#
# **Environment Set-up and Introduction to Jupyter Notebooks **
#
# Quick overview of class environment and how the Jupyter Notebook System works!
# ___
# **Python Overview **
#
# An overivew of the Basics of Python!
# ___
# * Review of Python Basics
#     * Data Types
#         * Numbers
#         * Strings
#         * Lists
#         * Dictionaries
#         * Tuples
#         * Sets
#
#     * Statements, methods and functions
#         * if elif else
#         * for loops
#         * while loops
#         * range()
#         * List comprehensions
#         * Methods
#         * Functions
#         * lambda expressions
# ____
# **Individual Exercise**
#
# * Simple Tic Tac Toe game *
# ___
#
# * OOP
#     * Objects
#     * Classes
#     * Methods
#     * Inheritance
# ____
# ** Partner Exercise  **
#
# * Program out a BlackJack game with Python OOP
#
# ___
# **Advanced Features of Python **
#
# * Built-in Functions
#     * Map
#     * Reduce
#     * Filter
#     * Zip
#     * Enumerate
#
# * Iterators & Generators
#     * Creating Generators
#
# * Advanced Python Modules
#     * Collections Module
#          * counter
#          * defaultdict
#          * OrderedDict
#          * namedtuple
#
#     * Datetime
#     * Python Debugger
#     * Timing Code (timeit)
#     * Regular Expressions
#
# ___
#
# **Introduction to NumPy **
#
# NumPy is a linear algebra library for Python and is our first step towards using Python for Data Analysis!
#
# * NumPy Basics
#  * Creating arrays
#  * Using Arrays and Scalars
#  * Indexing Arrays
#  * Array Transposition
#  * Universal Array Functions
#  * Array Processsing
#  * Array Input and Output
#
#
# ** NumPy Function Exercises **
#
# Fill out some functions Using NumPy!
# ___
# ** Question Exercises for NumPy  **
#
# 100 progressively harder questions for you to play around with and try to answer with NumPy!

# %% [markdown]
# _____
#
# **Pandas Lectures**
#
# * Lec 1 - Series
# * Lec 2 - DataFrames
# * Lec 3 - Index Objects
# * Lec 4 - Reindexing
# * Lec 5 - Selecting Entries
# * Lec 6 - Drop Entry
# * Lec 7 - Data Alignment
# * Lec 8 - Rank and Sort
# * Lec 9 - Summary Statistics
# * Lec 10 - Missing Data
# * Lec 11 - Index Hierarchy
# * Lec 12 - Reading and Writing Text Files
# * Lec 13 - JSON with Python
# * Lec 14 - HTML with Python
# * Lec 15 - Excel with Python
# * Lec 16 - Merge
# * Lec 17 - Merge on Index
# * Lec 18 - Concatenate
# * Lec 19 - Combining DataFrames
# * Lec 20 - Reshaping
# * Lec 21 - Pivoting
# * Lec 22 - Duplicates in DataFrames
# * Lec 23 - Mapping
# * Lec 24 - Replace
# * Lec 25 - Rename Index
# * Lec 26 - Binning
# * Lec 27 - Outliers
# * Lec 28 - Permutation
# * Lec 29 - GroupBy on DataFrames
# * Lec 30 - Groupby on Dict and Series
# * Lec 31 - Aggregation
# * Lec 32 - Splitting, Applying and Combining
# * Lec 33 - Cross-Tabulation
#
# ___
#
# **Pandas Exercise**
#
# * 6 exercises and solutions using example Data Sets
#
# ** Pandas Project **
#
# * Hospital Data Project *
# ___
#
# **Matplotlib Basics**
#
# * Lecture on Matplotlib Basics
# * Exercise on Simple plotting techniques

# %% [markdown]
# ____
# # ______
#
# ** SciKit Learn **
#
#
# **Basic Principles of Machine Learning and the Scikit-learn Interface**
# * What is Machine Learning?
# * Machine learning data layout
# * Supervised Learning
#     - Classification
#     - Regression
#     - Measuring performance
# * Unsupervised Learning
#     - Clustering
#     - Dimensionality Reduction
#     - Density Estimation
# * Evaluation of Learning Models
# * Choosing the right algorithm for your dataset
#
# ** Supervised learning in-depth **
# * Support Vector Machines
# * Decision Trees and Random Forests
#
# ** Unsupervised learning in-depth **
# * Dimensionality Reduction: Principal Component Analysis
# * Clustering: K Means
# * Application: image color compression
#
# ** Validation and Model Selection **
# * Overfitting, Underfitting, bias, and variance
# * Improving your fit: validation curves and learning curves
#
# ** Titanic Project (Optional) **
# * Example Walkthroughs of Kaggle's Titanic Machine Learning Competition
# ___
